# %%
import sys, numpy as np, pickle
if '/home/sagemaker-user/octis/OCTIS' not in sys.path: sys.path.append('/home/sagemaker-user/octis/OCTIS') 

from octis.models.LDA import LDA
from octis.models.LDA_gibbs import LDA_gibbs
from octis.models.LDA_tomopy import LDA_tomopy
from octis.models.NMF_scikit import NMF_scikit

from octis.dataset.dataset import Dataset
from octis.evaluation_metrics.diversity_metrics import TopicDiversity
from octis.evaluation_metrics.coherence_metrics import Coherence

from octis.optimization.optimizer import Optimizer
from skopt.space.space import Real, Integer, Categorical

from warnings import filterwarnings
filterwarnings('ignore')

# %%
#loadData
dbPedia = Dataset()
dbPedia.fetch_dataset('DBPedia_IT')

coherence = Coherence(texts=dbPedia.get_corpus(), topk=10, measure='c_v')

# %% [markdown]
# NMF_scikit

# %%
nmf_model_20 = NMF_scikit(num_topics=20, init='nndsvdar', alpha=0.0)
nmf_output_20 = nmf_model_20.train_model(dbPedia)
print('Topics:',*[' '.join(x) for x in nmf_output_20['topics']],sep='\n')
print(f'\nOverall Coherence Score: {coherence.score(nmf_output_20)}')

# %%
nmf_model_100 = NMF_scikit(num_topics=100, init='nndsvdar')
nmf_output_100 = nmf_model_100.train_model(dbPedia)
print('Topics:',*[' '.join(x) for x in nmf_output_100['topics']],sep='\n')
print(f'\nOverall Coherence Score: {coherence.score(nmf_output_100)}')
# Out:
# Topics:
# sin love life human hate live die death hell faith
# window manager application app screen advance event user top position
# game baseball night watch playoff pen hockey series devil score
# model engine manual build base datum science design assume seat
# phone company clipper network encryption office listen conversation voice wire
# card video slot bus vga controller local graphic performance mode
# drive hard floppy ide format controller meg tape boot internal
# key encryption escrow public algorithm security encrypt clipper secure secret
# file format directory convert download utility site create command edit
# car engine mile owner dealer tire auto brake insurance oil
# state jewish israeli arab country peace war land live attack
# team season playoff hockey expansion move star division final record
# religion belief claim atheist true evidence exist argument truth atheism
# image format convert processing datum graphic screen object quality resolution
# system user moral boot objective base access instal tape design
# post article newsgroup net message reply friend respond original summary
# program copy advance shareware convert manager domain error function taxis
# problem fix error solve solution dealer bad occur screen replace
# gun control firearm weapon crime criminal police carry rate defense
# good luck bad pretty job quality level offer reason nice
# run home score app compile load client fine network setup
# year ago season month past couple age remember week playoff
# light turn switch side signal ground radio front red blue
# work fine doesn instal idea project set perfectly stop luck
# price low cheap cost pay dealer high drop apple purchase
# bike ride motorcycle road mile dog rear front tire sport
# mail reply address advance order interested newsgroup internet site respond
# call friend order service place talk strike object leave city
# monitor vga apple video resolution cable screen mode connect switch
# book copy reference page guide author title publish history subject
# win lose series division wrong tie playoff close manager pay
# driver mode site support late load download update install device
# list mailing add request motif address product update regard complete
# armenian turkish genocide muslim russian population village massacre soviet war
# find hard check site interesting advance faq recently interested idea
# chip clipper algorithm encryption design pin secret escrow build technology
# people world live don person real bad insist talk care
# software package hardware tool product commercial produce copy manual apple
# time long spend happen waste access minute watch date real
# kill child die death woman attack parent soldier civilian dead
# question answer faq simple response real important regard case discussion
# disk hard copy floppy boot original format manual controller box
# bit mode block output byte datum random plane frame depth
# port serial pin parallel connect cable connector standard build set
# font type character set size text small default mode convert
# space orbit launch shuttle mission satellite cost station earth moon
# power supply voltage high current engine low control period case
# hear news story true local comment guy experience radio wasn
# color screen black draw white picture mode blue green true
# player stat league baseball average career hockey compare top total
# number serial order large address figure report guess tech telephone
# fire gas tank compound batf claim set tear agent place
# thing bad sort happen idea put kind funny pretty feel
# version late release support copy text export patch upgrade fix
# group news discussion newsgroup member discuss flame create vote concern
# goal score period shot lead save blue penalty playoff wing
# computer graphic science company project standard library performance author training
# line draw subject area wire output input simple plane cross
# law enforcement court legal federal crime rule police citizen apply
# speed mhz bus fast clock local performance cpu rate slow
# buy cheap money cost dealer brand order motorcycle spend quality
# give credit fact advice reference idea trade tax case ticket
# drug patient doctor effect disease treatment medical study test food
# back front put big bring move head seat road money
# printer print laser paper page quality output screen network sheet
# government encryption citizen private clipper tax agency federal money constitution
# play season trade hockey draft playoff defense ranger pick round
# modem fax internal connect external datum compression voice error apple
# point case view direction reference agree fact position miss side
# day week night serve month couple hour delete wing flame
# sell company package unit ship copy condition cover store bag
# man homosexual gay woman sex homosexuality sexual male study straight
# read article ago remember paper faq posting newsgroup haven learn
# information regard interested advance greatly project provide paper datum subject
# board pin video motherboard connector slot green upgrade add wire
# scsi ide controller device bus interface transfer support tape fast
# church christian catholic faith scripture doctrine issue tradition teaching member
# include shipping standard manual define library package disclaimer user type
# great deal shape watch excellent feel idea hockey flame clean
# send message copy receive request vote letter tape person hope
# write letter motif widget article application library language response quote
# start talk wait interested end stop happen easy season flame
# fan baseball cpu heat sport hockey watch cap air cool
# display server client support application screen motif set terminal widget
# word meaning language speak term refer greek text scripture verse
# part air pay american mention note package end body cut
# source code algorithm site library application package object widget compile
# machine user idea network instal ram set slow configuration command
# sound channel pretty doesn speaker suggestion sort hardware input nice
# memory meg ram mode video error virtual load serve map
# change oil mile set engine correct month service notice choose
# offer sale condition interested shipping trade excellent manual pay original
# mouse keyboard button move bus ball load clean command event
# make sense easy difference mistake statement money decision feel doesn
# show picture hockey study coverage baseball camera sign night pretty
# battery charge temperature lead leave cold replace remove cell heat
# email address response reply contact interested internet net advance prefer
# lot stuff delete big agree guess hell difference money guy
# hit pitch pitcher guy ball throw field walk base bat
# info greatly kind format project contact spec interested pointer regard
#
# Overall Coherence Score: 0.5514043199044094

# %% [markdown]
# LDA_gibbs

# %%
lda_model_20 = LDA_gibbs(num_topics=20, n_iter=1000)
lda_output_20 = lda_model_20.train_model(dbPedia)
print('Topics:',*[' '.join(x) for x in lda_output_20['topics']],sep='\n')
print(f'\nOverall Coherence Score: {coherence.score(lda_output_20)}')
# Out:
# Topics:
# drive card disk system driver work problem scsi monitor hard
# man church word people love sin life christian make homosexual
# car price sell good buy sale offer pay make engine
# key chip encryption phone clipper government system bit public privacy
# space launch system earth mission orbit satellite year planet station
# book write read article copy issue text paper find author
# people thing time start happen make child day hear year
# make people work time talk year president question money give
# system software include support user version base server run computer
# armenian people war government turkish jewish israeli kill country attack
# back time leave turn line work start day door side
# post mail send list address information group email question message
# image file color bit format graphic datum program display version
# power problem thing good make work time wire ground high
# file window program run set font entry application problem line
# study year number patient drug report high research rate health
# game team year play win player good season score goal
# gun law state government crime weapon people police firearm control
# people make point thing argument question claim exist evidence reason
# problem point time find case give theory form source part
#
# Overall Coherence Score: 0.614925230832194

# %%
lda_model_100 = LDA_gibbs(num_topics=100, n_iter=1000)
lda_output_100 = lda_model_100.train_model(dbPedia)
print('Topics:',*[' '.join(x) for x in lda_output_100['topics']],sep='\n')
print(f'\nOverall Coherence Score: {coherence.score(lda_output_100)}')

# %% [markdown]
# LDA_tomotopy

# %%
ldaTomopy_model_20 = LDA_tomopy(num_topics=20, max_iters=100)
ldaTomopy_output_20 = ldaTomopy_model_20.train_model(dbPedia)

print('Topics:',*[' '.join(x) for x in ldaTomopy_output_20['topics']],sep='\n')
print(f'\nOverall Coherence Score: {coherence.score(ldaTomopy_output_20)}')
# Out:
# Topics:
# make point people question thing claim good give read true
# armenian people kill turkish war government attack israeli jewish village
# system computer program technology provide design project information develop user
# file image program version server graphic format color display software
# space launch mission satellite earth orbit planet year shuttle solar
# people make time good work thing talk question job problem
# fire child batf agent police tank compound report warrant start
# game team year play win player good season score hit
# church word man book sin love life faith child christian
# price sell good offer sale mail include buy interested book
# law government gun state crime weapon control criminal public firearm
# religion people belief man atheist human homosexual moral religious atheism
# mail post list send information address group message article email
# key chip encryption clipper phone bit system number security algorithm
# people time start back day happen year leave thing hear
# year drug patient number health study disease report rate medical
# line control test level include entry datum section number output
# car good bike buy power problem engine drive make ride
# drive card disk system scsi work driver monitor video hard
# window problem run work program application system set file screen
#
# Overall Coherence Score: 0.6543158313581868

# %%
ldaTomopy_model_100 = LDA_tomopy(num_topics=100, max_iters=100)
ldaTomopy_output_100 = ldaTomopy_model_100.train_model(dbPedia)

print('Topics:',*[' '.join(x) for x in ldaTomopy_output_100['topics']],sep='\n')
print(f'\nOverall Coherence Score: {coherence.score(ldaTomopy_output_100)}')
# Out:
# Topics:
# law rule entry court make case legal note judge require
# man son father mother speak make child hell death pray
# observation science scientist experiment satellite activity main solar result field
# child homosexual male parent man sexual adult sex woman homosexuality
# goal period lead shot play penalty save score power line
# privacy technology computer encryption product communication system security government standard
# font printer print window screen character page laser driver size
# question answer text case die death claim act record give
# claim evidence show point find support case make account place
# human land arab live peace life jewish part territory give
# light vote theory good physical universe material matter include hole
# mail send message address internet information email network user request
# people state make person idea medium issue create business support
# term science idea sense part view scientific knowledge base group
# time happen thing make bring talk bad win turn people
# fire batf agent tank gas compound start warrant knock child
# bike ride road motorcycle traffic turn light advice mile buy
# game team play win player season year score playoff hockey
# world people history movement race today begin hand place century
# sound play great trade good hear music make channel speaker
# people start happen neighbor burn live throw stand hand kill
# make thing feel learn mind give mention part sort strong
# day time week year night body back start ago part
# atheist exist atheism existence statement assume argument belief fact logic
# religion belief christian religious faith church people truth true tradition
# system datum set model analysis work provide current computer require
# card video driver memory ram bus fast support window monitor
# time run work thing start year find hear ago couple
# system design database access software search product base control call
# include information source note list send volume number page release
# window widget application motif manager call version program work subject
# power battery heat supply remove part cool clean stuff plastic
# car engine drive front driver tire brake lock dealer wheel
# point line object picture draw plane find reference edge position
# build info source frame require information make time line result
# drive scsi controller ide disk hard bus device transfer boot
# key chip bit encryption algorithm escrow clipper encrypt public security
# image color format bit display program convert file software quality
# black thing unit radio local hear white remember dream hope
# buy order machine price give pay end release wait real
# point good make thing reason opinion change case question matter
# make talk decision president question general term situation day yesterday
# side back top blue leave put turn face thing make
# call leave woman home day back hour place night people
# argument conclusion fact true statement prove word assume present view
# buy price sell company cheap good make cost stuff market
# high low water temperature level pressure air noise speed heat
# people moral man gay homosexual society sex morality homosexuality human
# sin love church faith word life scripture man verse eternal
# drug school people kid risk child good life student education
# work field idea project energy model find distribution long experience
# disk software drive tape system hard copy program backup floppy
# people work job meet create continue support kind speak action
# year good ago time hit average long lot bad pretty
# find read group post information good interested source lot computer
# server run client machine display user remote file sun terminal
# kill people child attack body die dead civilian woman victim
# graphic package image format program file code tool include mail
# study year page number percent develop total culture report volume
# file section directory change read transfer format information index compress
# government people law country citizen state freedom civil individual protect
# planet earth moon mission orbit surface space degree solar sun
# ground control current wire voltage line circuit supply lead power
# food day eat effect make hour change person problem experience
# phone chip clipper encryption conversation criminal line government voice order
# datum software user hardware device provide time application data general
# call dog check number place match large area pretty city
# back hand work side short put arm pain foot bad
# problem work run error system fix fine time solution window
# israeli jewish village russian soldier population border state attack war
# set include define return shell follow build command character add
# war military force call plan time secret ship attack cut
# gun crime firearm control criminal weapon death defense assault violent
# question answer group faq discussion issue newsgroup number time note
# number time small difference large big problem give fact major
# offer sale price include sell good keyboard condition interested shipping
# post reply read article call response address mail write respond
# law police state weapon bill license carry illegal firearm person
# pay money cost fund tax private insurance spend care company
# report year press sign date announce give order state draft
# program research service conference include information computer contract call technology
# run hit time make double ball single average ticket field
# report increase number case high rate control age factor state
# oil change air year gas seat fuel mile room move
# book write word read find letter call good language reference
# government administration official member public group policy information issue today
# armenian turkish genocide greek muslim massacre government people soviet russian
# people thing good make lot bad time problem doesn find
# bit switch monitor output input mode screen work signal color
# true make people hate objective false world real perfect good
# file window program version run machine driver find comment load
# type resource function find error datum string environment variable default
# cover man copy issue bag annual black book guide sign
# space launch satellite shuttle mission rocket station program flight orbit
# pin chip apple computer board cpu cable connector mhz speed
# win fan make good bit line guess stuff hear case
# bit test fast speed read instruction case limit add mode
# list post posting people service net group site mailing make
# patient disease medical health doctor treatment cell blood effect care
# port modem serial mouse work connect system card board parallel
#
# Overall Coherence Score: 0.5865342093135976

# %% [markdown]
# HPOptimization

# %%
#NMF_scikit
nmf_model = NMF_scikit()
search_space = {"num_topics": Categorical([20,50,70,100]), "init": Categorical(['nndsvda','nndsvdar']), "alpha": Categorical([0.0,0.25,0.5,0.75,1.0])}
optimizer=Optimizer()

optResult=optimizer.optimize(nmf_model, dbPedia, coherence, search_space, save_path="./outputFiles", number_of_call=30, model_runs=5)
optResult.save_to_csv("NMFscikit_HOCoherence_dbPediaResults.csv")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
#LDA_gibbs
lda_model = LDA_gibbs()
search_space = {"n_topics": Categorical([20,50,70,100]), "n_iter": Categorical([100]), "alpha": Categorical([0.01,0.05,0.1,0.5,1.0]), "eta": Categorical([0.001,0.005,0.01,0.05,0.1])}
optimizer=Optimizer()

optResult=optimizer.optimize(lda_model, dbPedia, coherence, search_space, save_path="./outputFiles", number_of_call=30, model_runs=5)
optResult.save_to_csv("LDAgibbs_HOCoherence_dbPediaResults.csv")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1125281
# INFO:lda:<10> log likelihood: -680912
# INFO:lda:<20> log likelihood: -641000
# INFO:lda:<30> log likelihood: -628329
# INFO:lda:<40> log likelihood: -623778
# INFO:lda:<50> log likelihood: -621189
# INFO:lda:<60> log likelihood: -619464
# INFO:lda:<70> log likelihood: -618725
# INFO:lda:<80> log likelihood: -618105
# INFO:lda:<90> log likelihood: -616906
# INFO:lda:<99> log likelihood: -616999
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1125281
# INFO:lda:<10> log likelihood: -676659
# INFO:lda:<20> log likelihood: -640892
# INFO:lda:<30> log likelihood: -629206
# INFO:lda:<40> log likelihood: -623752
# INFO:lda:<50> log likelihood: -620413
# INFO:lda:<60> log likelihood: -617877
# INFO:lda:<70> log likelihood: -617321
# INFO:lda:<80> log likelihood: -616936
# INFO:lda:<90> log likelihood: -615370
# INFO:lda:<99> log likelihood: -616078
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1125281
# INFO:lda:<10> log likelihood: -677920
# INFO:lda:<20> log likelihood: -640909
# INFO:lda:<30> log likelihood: -629883
# INFO:lda:<40> log likelihood: -624519
# INFO:lda:<50> log likelihood: -621496
# INFO:lda:<60> log likelihood: -620260
# INFO:lda:<70> log likelihood: -618845
# INFO:lda:<80> log likelihood: -618098
# INFO:lda:<90> log likelihood: -617276
# INFO:lda:<99> log likelihood: -616106
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1125281
# INFO:lda:<10> log likelihood: -675018
# INFO:lda:<20> log likelihood: -638484
# INFO:lda:<30> log likelihood: -627167
# INFO:lda:<40> log likelihood: -622040
# INFO:lda:<50> log likelihood: -619821
# INFO:lda:<60> log likelihood: -618431
# INFO:lda:<70> log likelihood: -617666
# INFO:lda:<80> log likelihood: -617395
# INFO:lda:<90> log likelihood: -615878
# INFO:lda:<99> log likelihood: -615565
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1125281
# INFO:lda:<10> log likelihood: -676764
# INFO:lda:<20> log likelihood: -637071
# INFO:lda:<30> log likelihood: -627336
# INFO:lda:<40> log likelihood: -622078
# INFO:lda:<50> log likelihood: -619926
# INFO:lda:<60> log likelihood: -618834
# INFO:lda:<70> log likelihood: -618180
# INFO:lda:<80> log likelihood: -617517
# INFO:lda:<90> log likelihood: -616312
# INFO:lda:<99> log likelihood: -616091
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1278996
# INFO:lda:<10> log likelihood: -687704
# INFO:lda:<20> log likelihood: -651805
# INFO:lda:<30> log likelihood: -639656
# INFO:lda:<40> log likelihood: -633314
# INFO:lda:<50> log likelihood: -627390
# INFO:lda:<60> log likelihood: -624271
# INFO:lda:<70> log likelihood: -621647
# INFO:lda:<80> log likelihood: -619495
# INFO:lda:<90> log likelihood: -618436
# INFO:lda:<99> log likelihood: -615828
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1278996
# INFO:lda:<10> log likelihood: -686636
# INFO:lda:<20> log likelihood: -652026
# INFO:lda:<30> log likelihood: -641181
# INFO:lda:<40> log likelihood: -633571
# INFO:lda:<50> log likelihood: -629245
# INFO:lda:<60> log likelihood: -626494
# INFO:lda:<70> log likelihood: -623590
# INFO:lda:<80> log likelihood: -620629
# INFO:lda:<90> log likelihood: -618919
# INFO:lda:<99> log likelihood: -617564
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1278996
# INFO:lda:<10> log likelihood: -685786
# INFO:lda:<20> log likelihood: -652315
# INFO:lda:<30> log likelihood: -640116
# INFO:lda:<40> log likelihood: -633570
# INFO:lda:<50> log likelihood: -628072
# INFO:lda:<60> log likelihood: -625345
# INFO:lda:<70> log likelihood: -623583
# INFO:lda:<80> log likelihood: -621656
# INFO:lda:<90> log likelihood: -619233
# INFO:lda:<99> log likelihood: -618196
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1278996
# INFO:lda:<10> log likelihood: -690304
# INFO:lda:<20> log likelihood: -653723
# INFO:lda:<30> log likelihood: -641123
# INFO:lda:<40> log likelihood: -633392
# INFO:lda:<50> log likelihood: -628299
# INFO:lda:<60> log likelihood: -624684
# INFO:lda:<70> log likelihood: -622534
# INFO:lda:<80> log likelihood: -621172
# INFO:lda:<90> log likelihood: -618859
# INFO:lda:<99> log likelihood: -617119
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1278996
# INFO:lda:<10> log likelihood: -689830
# INFO:lda:<20> log likelihood: -653961
# INFO:lda:<30> log likelihood: -640957
# INFO:lda:<40> log likelihood: -633307
# INFO:lda:<50> log likelihood: -628045
# INFO:lda:<60> log likelihood: -624599
# INFO:lda:<70> log likelihood: -621786
# INFO:lda:<80> log likelihood: -619309
# INFO:lda:<90> log likelihood: -617258
# INFO:lda:<99> log likelihood: -616221
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1092776
# INFO:lda:<10> log likelihood: -882542
# INFO:lda:<20> log likelihood: -829390
# INFO:lda:<30> log likelihood: -811678
# INFO:lda:<40> log likelihood: -803770
# INFO:lda:<50> log likelihood: -800032
# INFO:lda:<60> log likelihood: -796057
# INFO:lda:<70> log likelihood: -796594
# INFO:lda:<80> log likelihood: -796337
# INFO:lda:<90> log likelihood: -796131
# INFO:lda:<99> log likelihood: -793839
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1092776
# INFO:lda:<10> log likelihood: -879313
# INFO:lda:<20> log likelihood: -830393
# INFO:lda:<30> log likelihood: -812968
# INFO:lda:<40> log likelihood: -803177
# INFO:lda:<50> log likelihood: -801434
# INFO:lda:<60> log likelihood: -799792
# INFO:lda:<70> log likelihood: -797553
# INFO:lda:<80> log likelihood: -796548
# INFO:lda:<90> log likelihood: -796412
# INFO:lda:<99> log likelihood: -795902
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1092776
# INFO:lda:<10> log likelihood: -884366
# INFO:lda:<20> log likelihood: -831708
# INFO:lda:<30> log likelihood: -813216
# INFO:lda:<40> log likelihood: -809146
# INFO:lda:<50> log likelihood: -804524
# INFO:lda:<60> log likelihood: -802898
# INFO:lda:<70> log likelihood: -801834
# INFO:lda:<80> log likelihood: -799627
# INFO:lda:<90> log likelihood: -798866
# INFO:lda:<99> log likelihood: -799962
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1092776
# INFO:lda:<10> log likelihood: -881831
# INFO:lda:<20> log likelihood: -826285
# INFO:lda:<30> log likelihood: -812605
# INFO:lda:<40> log likelihood: -807193
# INFO:lda:<50> log likelihood: -804807
# INFO:lda:<60> log likelihood: -801398
# INFO:lda:<70> log likelihood: -801839
# INFO:lda:<80> log likelihood: -798613
# INFO:lda:<90> log likelihood: -798657
# INFO:lda:<99> log likelihood: -797356
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1092776
# INFO:lda:<10> log likelihood: -881661
# INFO:lda:<20> log likelihood: -829734
# INFO:lda:<30> log likelihood: -814456
# INFO:lda:<40> log likelihood: -807948
# INFO:lda:<50> log likelihood: -804575
# INFO:lda:<60> log likelihood: -800273
# INFO:lda:<70> log likelihood: -799124
# INFO:lda:<80> log likelihood: -798958
# INFO:lda:<90> log likelihood: -797824
# INFO:lda:<99> log likelihood: -797626
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1068273
# INFO:lda:<10> log likelihood: -662781
# INFO:lda:<20> log likelihood: -626547
# INFO:lda:<30> log likelihood: -616798
# INFO:lda:<40> log likelihood: -610977
# INFO:lda:<50> log likelihood: -607166
# INFO:lda:<60> log likelihood: -604474
# INFO:lda:<70> log likelihood: -602573
# INFO:lda:<80> log likelihood: -600885
# INFO:lda:<90> log likelihood: -599880
# INFO:lda:<99> log likelihood: -598505
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1068273
# INFO:lda:<10> log likelihood: -662331
# INFO:lda:<20> log likelihood: -627260
# INFO:lda:<30> log likelihood: -614340
# INFO:lda:<40> log likelihood: -607387
# INFO:lda:<50> log likelihood: -603587
# INFO:lda:<60> log likelihood: -601602
# INFO:lda:<70> log likelihood: -600467
# INFO:lda:<80> log likelihood: -598913
# INFO:lda:<90> log likelihood: -598245
# INFO:lda:<99> log likelihood: -597363
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1068273
# INFO:lda:<10> log likelihood: -670461
# INFO:lda:<20> log likelihood: -630801
# INFO:lda:<30> log likelihood: -619051
# INFO:lda:<40> log likelihood: -613380
# INFO:lda:<50> log likelihood: -609429
# INFO:lda:<60> log likelihood: -605237
# INFO:lda:<70> log likelihood: -602751
# INFO:lda:<80> log likelihood: -601719
# INFO:lda:<90> log likelihood: -600395
# INFO:lda:<99> log likelihood: -599362
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1068273
# INFO:lda:<10> log likelihood: -665943
# INFO:lda:<20> log likelihood: -629520
# INFO:lda:<30> log likelihood: -616021
# INFO:lda:<40> log likelihood: -608528
# INFO:lda:<50> log likelihood: -603887
# INFO:lda:<60> log likelihood: -601860
# INFO:lda:<70> log likelihood: -599525
# INFO:lda:<80> log likelihood: -597631
# INFO:lda:<90> log likelihood: -596948
# INFO:lda:<99> log likelihood: -596012
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1068273
# INFO:lda:<10> log likelihood: -665949
# INFO:lda:<20> log likelihood: -630395
# INFO:lda:<30> log likelihood: -618216
# INFO:lda:<40> log likelihood: -611889
# INFO:lda:<50> log likelihood: -606625
# INFO:lda:<60> log likelihood: -604556
# INFO:lda:<70> log likelihood: -602487
# INFO:lda:<80> log likelihood: -600899
# INFO:lda:<90> log likelihood: -599607
# INFO:lda:<99> log likelihood: -598727
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1139706
# INFO:lda:<10> log likelihood: -669366
# INFO:lda:<20> log likelihood: -631040
# INFO:lda:<30> log likelihood: -615995
# INFO:lda:<40> log likelihood: -606831
# INFO:lda:<50> log likelihood: -601128
# INFO:lda:<60> log likelihood: -597032
# INFO:lda:<70> log likelihood: -593954
# INFO:lda:<80> log likelihood: -591448
# INFO:lda:<90> log likelihood: -589883
# INFO:lda:<99> log likelihood: -588547
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1139706
# INFO:lda:<10> log likelihood: -674109
# INFO:lda:<20> log likelihood: -635501
# INFO:lda:<30> log likelihood: -616862
# INFO:lda:<40> log likelihood: -606971
# INFO:lda:<50> log likelihood: -600769
# INFO:lda:<60> log likelihood: -596499
# INFO:lda:<70> log likelihood: -592811
# INFO:lda:<80> log likelihood: -589805
# INFO:lda:<90> log likelihood: -587707
# INFO:lda:<99> log likelihood: -586559
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1139706
# INFO:lda:<10> log likelihood: -670054
# INFO:lda:<20> log likelihood: -628684
# INFO:lda:<30> log likelihood: -613207
# INFO:lda:<40> log likelihood: -603801
# INFO:lda:<50> log likelihood: -599121
# INFO:lda:<60> log likelihood: -595202
# INFO:lda:<70> log likelihood: -592036
# INFO:lda:<80> log likelihood: -589878
# INFO:lda:<90> log likelihood: -588699
# INFO:lda:<99> log likelihood: -587465
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1139706
# INFO:lda:<10> log likelihood: -672168
# INFO:lda:<20> log likelihood: -633659
# INFO:lda:<30> log likelihood: -617405
# INFO:lda:<40> log likelihood: -606932
# INFO:lda:<50> log likelihood: -600688
# INFO:lda:<60> log likelihood: -595859
# INFO:lda:<70> log likelihood: -592818
# INFO:lda:<80> log likelihood: -590310
# INFO:lda:<90> log likelihood: -588038
# INFO:lda:<99> log likelihood: -586929
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1139706
# INFO:lda:<10> log likelihood: -671661
# INFO:lda:<20> log likelihood: -632516
# INFO:lda:<30> log likelihood: -616902
# INFO:lda:<40> log likelihood: -607257
# INFO:lda:<50> log likelihood: -601815
# INFO:lda:<60> log likelihood: -598017
# INFO:lda:<70> log likelihood: -594709
# INFO:lda:<80> log likelihood: -591899
# INFO:lda:<90> log likelihood: -589909
# INFO:lda:<99> log likelihood: -588282
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1325735
# INFO:lda:<10> log likelihood: -696953
# INFO:lda:<20> log likelihood: -650512
# INFO:lda:<30> log likelihood: -628790
# INFO:lda:<40> log likelihood: -616660
# INFO:lda:<50> log likelihood: -608913
# INFO:lda:<60> log likelihood: -604216
# INFO:lda:<70> log likelihood: -600553
# INFO:lda:<80> log likelihood: -597249
# INFO:lda:<90> log likelihood: -595220
# INFO:lda:<99> log likelihood: -592985
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1325735
# INFO:lda:<10> log likelihood: -693123
# INFO:lda:<20> log likelihood: -648465
# INFO:lda:<30> log likelihood: -628196
# INFO:lda:<40> log likelihood: -615969
# INFO:lda:<50> log likelihood: -607522
# INFO:lda:<60> log likelihood: -602170
# INFO:lda:<70> log likelihood: -597607
# INFO:lda:<80> log likelihood: -594160
# INFO:lda:<90> log likelihood: -592741
# INFO:lda:<99> log likelihood: -591091
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1325735
# INFO:lda:<10> log likelihood: -693962
# INFO:lda:<20> log likelihood: -648329
# INFO:lda:<30> log likelihood: -625583
# INFO:lda:<40> log likelihood: -613811
# INFO:lda:<50> log likelihood: -605703
# INFO:lda:<60> log likelihood: -600928
# INFO:lda:<70> log likelihood: -596800
# INFO:lda:<80> log likelihood: -593832
# INFO:lda:<90> log likelihood: -591692
# INFO:lda:<99> log likelihood: -590242
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1325735
# INFO:lda:<10> log likelihood: -695889
# INFO:lda:<20> log likelihood: -649124
# INFO:lda:<30> log likelihood: -627052
# INFO:lda:<40> log likelihood: -615428
# INFO:lda:<50> log likelihood: -608054
# INFO:lda:<60> log likelihood: -603044
# INFO:lda:<70> log likelihood: -599454
# INFO:lda:<80> log likelihood: -596634
# INFO:lda:<90> log likelihood: -594703
# INFO:lda:<99> log likelihood: -593223
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1325735
# INFO:lda:<10> log likelihood: -696015
# INFO:lda:<20> log likelihood: -649175
# INFO:lda:<30> log likelihood: -627226
# INFO:lda:<40> log likelihood: -614303
# INFO:lda:<50> log likelihood: -605867
# INFO:lda:<60> log likelihood: -600782
# INFO:lda:<70> log likelihood: -597015
# INFO:lda:<80> log likelihood: -594684
# INFO:lda:<90> log likelihood: -592560
# INFO:lda:<99> log likelihood: -591584
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1117720
# INFO:lda:<10> log likelihood: -680629
# INFO:lda:<20> log likelihood: -642301
# INFO:lda:<30> log likelihood: -625918
# INFO:lda:<40> log likelihood: -618277
# INFO:lda:<50> log likelihood: -612236
# INFO:lda:<60> log likelihood: -608160
# INFO:lda:<70> log likelihood: -604840
# INFO:lda:<80> log likelihood: -602227
# INFO:lda:<90> log likelihood: -600545
# INFO:lda:<99> log likelihood: -599396
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1117720
# INFO:lda:<10> log likelihood: -675300
# INFO:lda:<20> log likelihood: -634372
# INFO:lda:<30> log likelihood: -621628
# INFO:lda:<40> log likelihood: -615181
# INFO:lda:<50> log likelihood: -610478
# INFO:lda:<60> log likelihood: -607961
# INFO:lda:<70> log likelihood: -605842
# INFO:lda:<80> log likelihood: -603823
# INFO:lda:<90> log likelihood: -602595
# INFO:lda:<99> log likelihood: -601538
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1117720
# INFO:lda:<10> log likelihood: -672251
# INFO:lda:<20> log likelihood: -636343
# INFO:lda:<30> log likelihood: -622900
# INFO:lda:<40> log likelihood: -615645
# INFO:lda:<50> log likelihood: -610794
# INFO:lda:<60> log likelihood: -607389
# INFO:lda:<70> log likelihood: -603968
# INFO:lda:<80> log likelihood: -601963
# INFO:lda:<90> log likelihood: -599353
# INFO:lda:<99> log likelihood: -597686
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1117720
# INFO:lda:<10> log likelihood: -676851
# INFO:lda:<20> log likelihood: -639070
# INFO:lda:<30> log likelihood: -623691
# INFO:lda:<40> log likelihood: -614463
# INFO:lda:<50> log likelihood: -609323
# INFO:lda:<60> log likelihood: -604712
# INFO:lda:<70> log likelihood: -601203
# INFO:lda:<80> log likelihood: -599098
# INFO:lda:<90> log likelihood: -597582
# INFO:lda:<99> log likelihood: -596148
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1117720
# INFO:lda:<10> log likelihood: -674462
# INFO:lda:<20> log likelihood: -634684
# INFO:lda:<30> log likelihood: -621229
# INFO:lda:<40> log likelihood: -614454
# INFO:lda:<50> log likelihood: -609144
# INFO:lda:<60> log likelihood: -605390
# INFO:lda:<70> log likelihood: -602198
# INFO:lda:<80> log likelihood: -600068
# INFO:lda:<90> log likelihood: -598809
# INFO:lda:<99> log likelihood: -597141
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -961010
# INFO:lda:<10> log likelihood: -677698
# INFO:lda:<20> log likelihood: -643505
# INFO:lda:<30> log likelihood: -637695
# INFO:lda:<40> log likelihood: -634161
# INFO:lda:<50> log likelihood: -633478
# INFO:lda:<60> log likelihood: -633531
# INFO:lda:<70> log likelihood: -632395
# INFO:lda:<80> log likelihood: -632472
# INFO:lda:<90> log likelihood: -631961
# INFO:lda:<99> log likelihood: -631759
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -961010
# INFO:lda:<10> log likelihood: -670415
# INFO:lda:<20> log likelihood: -644350
# INFO:lda:<30> log likelihood: -637848
# INFO:lda:<40> log likelihood: -636690
# INFO:lda:<50> log likelihood: -635836
# INFO:lda:<60> log likelihood: -635371
# INFO:lda:<70> log likelihood: -633827
# INFO:lda:<80> log likelihood: -633523
# INFO:lda:<90> log likelihood: -632896
# INFO:lda:<99> log likelihood: -633050
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -961010
# INFO:lda:<10> log likelihood: -682617
# INFO:lda:<20> log likelihood: -646337
# INFO:lda:<30> log likelihood: -639022
# INFO:lda:<40> log likelihood: -636330
# INFO:lda:<50> log likelihood: -634446
# INFO:lda:<60> log likelihood: -634048
# INFO:lda:<70> log likelihood: -633939
# INFO:lda:<80> log likelihood: -633325
# INFO:lda:<90> log likelihood: -633299
# INFO:lda:<99> log likelihood: -632904
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -961010
# INFO:lda:<10> log likelihood: -677587
# INFO:lda:<20> log likelihood: -642708
# INFO:lda:<30> log likelihood: -637492
# INFO:lda:<40> log likelihood: -635320
# INFO:lda:<50> log likelihood: -634230
# INFO:lda:<60> log likelihood: -633172
# INFO:lda:<70> log likelihood: -632981
# INFO:lda:<80> log likelihood: -632499
# INFO:lda:<90> log likelihood: -632422
# INFO:lda:<99> log likelihood: -632146
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -961010
# INFO:lda:<10> log likelihood: -678760
# INFO:lda:<20> log likelihood: -645800
# INFO:lda:<30> log likelihood: -639137
# INFO:lda:<40> log likelihood: -636685
# INFO:lda:<50> log likelihood: -635529
# INFO:lda:<60> log likelihood: -633783
# INFO:lda:<70> log likelihood: -633620
# INFO:lda:<80> log likelihood: -633090
# INFO:lda:<90> log likelihood: -633012
# INFO:lda:<99> log likelihood: -633315
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# ...
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1206354
# INFO:lda:<10> log likelihood: -699797
# INFO:lda:<20> log likelihood: -656519
# INFO:lda:<30> log likelihood: -643088
# INFO:lda:<40> log likelihood: -637775
# INFO:lda:<50> log likelihood: -634179
# INFO:lda:<60> log likelihood: -631593
# INFO:lda:<70> log likelihood: -630270
# INFO:lda:<80> log likelihood: -629511
# INFO:lda:<90> log likelihood: -628886
# INFO:lda:<99> log likelihood: -628755
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1206354
# INFO:lda:<10> log likelihood: -695495
# INFO:lda:<20> log likelihood: -655339
# INFO:lda:<30> log likelihood: -641407
# INFO:lda:<40> log likelihood: -636160
# INFO:lda:<50> log likelihood: -631594
# INFO:lda:<60> log likelihood: -631224
# INFO:lda:<70> log likelihood: -629031
# INFO:lda:<80> log likelihood: -628362
# INFO:lda:<90> log likelihood: -627348
# INFO:lda:<99> log likelihood: -626099
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 100
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1206354
# INFO:lda:<10> log likelihood: -695081
# INFO:lda:<20> log likelihood: -652809
# INFO:lda:<30> log likelihood: -639502
# INFO:lda:<40> log likelihood: -633794
# INFO:lda:<50> log likelihood: -632212
# INFO:lda:<60> log likelihood: -630716
# INFO:lda:<70> log likelihood: -628847
# INFO:lda:<80> log likelihood: -627975
# INFO:lda:<90> log likelihood: -627463
# INFO:lda:<99> log likelihood: -627531
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 70
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1470012
# INFO:lda:<10> log likelihood: -722959
# INFO:lda:<20> log likelihood: -680407
# INFO:lda:<30> log likelihood: -659720
# INFO:lda:<40> log likelihood: -648544
# INFO:lda:<50> log likelihood: -640513
# INFO:lda:<60> log likelihood: -634502
# INFO:lda:<70> log likelihood: -629763
# INFO:lda:<80> log likelihood: -625321
# INFO:lda:<90> log likelihood: -621957
# INFO:lda:<99> log likelihood: -619263
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 70
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1470012
# INFO:lda:<10> log likelihood: -721258
# INFO:lda:<20> log likelihood: -679377
# INFO:lda:<30> log likelihood: -659628
# INFO:lda:<40> log likelihood: -647873
# INFO:lda:<50> log likelihood: -639524
# INFO:lda:<60> log likelihood: -633215
# INFO:lda:<70> log likelihood: -628611
# INFO:lda:<80> log likelihood: -624554
# INFO:lda:<90> log likelihood: -621699
# INFO:lda:<99> log likelihood: -619153
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 70
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1470012
# INFO:lda:<10> log likelihood: -717518
# INFO:lda:<20> log likelihood: -675706
# INFO:lda:<30> log likelihood: -657609
# INFO:lda:<40> log likelihood: -645158
# INFO:lda:<50> log likelihood: -638273
# INFO:lda:<60> log likelihood: -631273
# INFO:lda:<70> log likelihood: -626318
# INFO:lda:<80> log likelihood: -621873
# INFO:lda:<90> log likelihood: -618769
# INFO:lda:<99> log likelihood: -616432
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 70
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1470012
# INFO:lda:<10> log likelihood: -719780
# INFO:lda:<20> log likelihood: -678268
# INFO:lda:<30> log likelihood: -657810
# INFO:lda:<40> log likelihood: -646129
# INFO:lda:<50> log likelihood: -637910
# INFO:lda:<60> log likelihood: -632590
# INFO:lda:<70> log likelihood: -628287
# INFO:lda:<80> log likelihood: -624608
# INFO:lda:<90> log likelihood: -621869
# INFO:lda:<99> log likelihood: -619701
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 70
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1470012
# INFO:lda:<10> log likelihood: -717489
# INFO:lda:<20> log likelihood: -676000
# INFO:lda:<30> log likelihood: -657188
# INFO:lda:<40> log likelihood: -645489
# INFO:lda:<50> log likelihood: -636631
# INFO:lda:<60> log likelihood: -630986
# INFO:lda:<70> log likelihood: -626278
# INFO:lda:<80> log likelihood: -623186
# INFO:lda:<90> log likelihood: -620202
# INFO:lda:<99> log likelihood: -617391
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1058390
# INFO:lda:<10> log likelihood: -656663
# INFO:lda:<20> log likelihood: -616375
# INFO:lda:<30> log likelihood: -606130
# INFO:lda:<40> log likelihood: -600836
# INFO:lda:<50> log likelihood: -598700
# INFO:lda:<60> log likelihood: -596976
# INFO:lda:<70> log likelihood: -595324
# INFO:lda:<80> log likelihood: -594467
# INFO:lda:<90> log likelihood: -594142
# INFO:lda:<99> log likelihood: -593093
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1058390
# INFO:lda:<10> log likelihood: -660083
# INFO:lda:<20> log likelihood: -618304
# INFO:lda:<30> log likelihood: -601400
# INFO:lda:<40> log likelihood: -595777
# INFO:lda:<50> log likelihood: -593571
# INFO:lda:<60> log likelihood: -592318
# INFO:lda:<70> log likelihood: -591848
# INFO:lda:<80> log likelihood: -590975
# INFO:lda:<90> log likelihood: -590898
# INFO:lda:<99> log likelihood: -590350
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1058390
# INFO:lda:<10> log likelihood: -659000
# INFO:lda:<20> log likelihood: -618917
# INFO:lda:<30> log likelihood: -606611
# INFO:lda:<40> log likelihood: -599886
# INFO:lda:<50> log likelihood: -596816
# INFO:lda:<60> log likelihood: -595432
# INFO:lda:<70> log likelihood: -594259
# INFO:lda:<80> log likelihood: -593172
# INFO:lda:<90> log likelihood: -592494
# INFO:lda:<99> log likelihood: -591469
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1058390
# INFO:lda:<10> log likelihood: -659061
# INFO:lda:<20> log likelihood: -616504
# INFO:lda:<30> log likelihood: -604185
# INFO:lda:<40> log likelihood: -599938
# INFO:lda:<50> log likelihood: -597222
# INFO:lda:<60> log likelihood: -595529
# INFO:lda:<70> log likelihood: -594218
# INFO:lda:<80> log likelihood: -593125
# INFO:lda:<90> log likelihood: -592843
# INFO:lda:<99> log likelihood: -592399
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:lda:n_documents: 4251
# INFO:lda:vocab_size: 2047
# INFO:lda:n_words: 87706
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 100
# INFO:lda:<0> log likelihood: -1058390
# INFO:lda:<10> log likelihood: -665810
# INFO:lda:<20> log likelihood: -622616
# INFO:lda:<30> log likelihood: -604755
# INFO:lda:<40> log likelihood: -598172
# INFO:lda:<50> log likelihood: -595042
# INFO:lda:<60> log likelihood: -593823
# INFO:lda:<70> log likelihood: -592791
# INFO:lda:<80> log likelihood: -592510
# INFO:lda:<90> log likelihood: -591729
# INFO:lda:<99> log likelihood: -591087
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents

# %%
#LDA_tomopy
ldatomopy_model = LDA_tomopy()
search_space = {"num_topics": Categorical([20,50,70,100]), "max_iters": Categorical([100]), "alpha": Categorical([0.01,0.05,0.1,0.5,1.0]), "eta": Categorical([0.001,0.005,0.01,0.05,0.1])}
optimizer=Optimizer()

optResult=optimizer.optimize(ldatomopy_model, dbPedia, coherence, search_space, save_path="./outputFiles", number_of_call=30, model_runs=5)
optResult.save_to_csv("LDAtomopy_HOCoherence_dbPediaResults.csv")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# ...
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.probability_estimation:using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:WordOccurrenceAccumulator accumulated stats from 5000 documents

# %%
#ProcessingDatasets - Sorting
import pandas as pd
df=pd.read_csv('/home/sagemaker-user/octis/LDAgibbs_HOCoherence_dbPediaResults.csv')
df.sort_values(by='Median(model_runs)',inplace=True, ascending=False)
df.to_csv('/home/sagemaker-user/octis/LDAgibbs_HOCoherence_dbPediaResults.csv')
