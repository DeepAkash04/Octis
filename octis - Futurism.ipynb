# %%
import sys
import pandas as pd
if 'E:\\Rashi\\octis\\OCTIS' not in sys.path: sys.path.append('E:\\Rashi\\octis\\OCTIS') 

from octis.models.LDA import LDA
from octis.models.LDA_gibbs import LDA_gibbs
from octis.models.LDA_tomopy import LDA_tomopy
from octis.models.NMF_scikit import NMF_scikit

from octis.dataset.dataset import Dataset
from octis.evaluation_metrics.diversity_metrics import KLDivergence
from octis.evaluation_metrics.coherence_metrics import Coherence
from octis.evaluation_metrics.perplexity_metrics import Perplexity

from octis.optimization.optimizer import Optimizer
from skopt.space.space import Real, Integer, Categorical

from warnings import filterwarnings
filterwarnings('ignore')

# %%
#loadCustomData
import os, numpy as np, pandas as pd

fut=pd.read_csv("E:\\Rashi\\datasets\\articles_futurism_year\\articles_futurism_2022.csv")
fut.drop_duplicates(inplace=True,ignore_index=True)
docs=[doc.replace('\n',' ')+' \n' for doc in fut.content.to_list()]

try:
    os.remove('E:\\Rashi\\octis\\articles_futurism_2022_content.txt')
except OSError:
    pass

with open('E:\\Rashi\\octis\\articles_futurism_2022_content.txt','a',encoding="utf-8") as file:
    file.writelines(docs)

# %%
#preprocessData
from octis.preprocessing.preprocessing import Preprocessing
import spacy, string
spacy.load('en_core_web_sm')
from spacy.lang.en import stop_words
stop_words=stop_words.STOP_WORDS


stop_words=list(stop_words)+['share','article','futurism']
preprocessor = Preprocessing(vocabulary=None, max_features=None,
                             remove_punctuation=True, punctuation=string.punctuation,
                             lemmatize=True, stopword_list=stop_words,
                             min_chars=1, min_words_docs=50)

fut_dataset = preprocessor.preprocess_dataset(documents_path='E:\\Rashi\\octis\\articles_futurism_2022_content.txt')

# %%
# #dump/LoadPickleData
import pickle

# # #dumpPickleFile
# with open('E:\\Rashi\\octis\\futurism_2022_content_preprocessed.pkl','wb') as file:
#     pickle.dump(fut_dataset,file)

# # readPickleFile
with open('E:\\Rashi\\octis\\helperFiles\\futurism_2022_content_preprocessed.pkl','rb') as file:
    fut_dataset=pickle.load(file)

coherence = Coherence(texts=fut_dataset.get_corpus(), topk=10, measure='c_v')

# %%
fut_dataset

# %%
NMF

# %%
nmf_model = NMF_scikit(num_topics=37, init='nndsvdar', alpha=0.08)
nmf_output = nmf_model.train_model(fut_dataset)
print('Topics:',*[' '.join(x) for x in nmf_output['topics']],sep='\n')
print(f'\nOverall Coherence Score: {coherence.score(nmf_output)}')

# %%
LDA_gibbs

# %%
lda_model = LDA_gibbs(num_topics=10, n_iter=200, random_state=100, alpha=0.01, eta=0.001)
lda_output = lda_model.train_model(fut_dataset)
print('Topics:',*[' '.join(x) for x in lda_output['topics']],sep='\n')

coherence = Coherence(texts=fut_dataset.get_corpus(), topk=10, measure='c_v')
kld = KLDivergence()
perplex = Perplexity()
print(f'\nOverall Coherence Score: {coherence.score(lda_output)}  \nKLD Score: {kld.score(lda_output)}  \nPerplexity Score: {perplex.score(lda_output)}')
# Out:
# WARNING:lda:all zero column in document-term matrix found
# Topics:
# like way world come point life star look water think
# good use set printer easy design little work pad material
# use year new time energy change system team able long
# day prime amazon deal good headphone sound speaker save ear
# musk company twitter tesla crypto elon tell ceo report people
# game tv gaming good play smart laptop keyboard pro like
# battery watch use apple phone charge device pro feature good
# space nasa tell launch earth nft human spacex station accord
# camera inch light good use quality kid video feature look
# software use like good company feature include earbud tool free
#
# Overall Coherence Score: 0.5116750316501677
# KLD Score: 4.068518611226207
# Perplexity Score: {'perplexity': 2.836535637689653e+69, 'AIC': 6707104.847594256, 'BIC': 6707152.240960529}

# %%
LDA_tomopy

# %%
ldaTomopy_model = LDA_tomopy(num_topics=10, max_iters=100)
ldaTomopy_output = ldaTomopy_model.train_model(fut_dataset)
print('Topics:',*[' '.join(x) for x in ldaTomopy_output['topics']],sep='\n')

coherence = Coherence(texts=fut_dataset.get_corpus(), topk=10, measure='c_v')
kld = KLDivergence()
perplex = Perplexity()
print(f'\nOverall Coherence Score: {coherence.score(ldaTomopy_output)}  \nKLD Score: {kld.score(ldaTomopy_output)}')
# Out:
# Topics:
# battery good feature camera use light video kid inch size
# use good design keyboard software turntable key include product type
# use phone time case apple allow technology like fly wallet
# day prime deal amazon good printer save big d print
# like pet robot smart vacuum home point cat heat way
# musk company twitter tesla tell people crypto elon spacex report
# tv sound good headphone pro inch audio smart screen music
# space nasa year star earth scientist launch tell human planet
# game watch play controller switch good like console gps nintendo
# laptop gaming inch device good pad usb cool mouse detector
#
# Overall Coherence Score: 0.5420507718138781
# KLD Score: 3.899872869699644

# %%
HPOptimization

# %%
nmf_model=NMF_scikit()
search_space = {"num_topics": Categorical([50,70,100,120,150]), "init": Categorical(['nndsvd','nndsvda','nndsvdar']), "alpha": Categorical([0.0,0.25,0.5,0.75,1.0])}
optimizer=Optimizer()

optResult=optimizer.optimize(nmf_model, fut_dataset, coherence, search_space, save_path="./outputFiles", number_of_call=30, model_runs=5)
optResult.save_to_csv("NMF_HOCoherence_futurismResults.csv")

# %%
lda_model=LDA_gibbs()
search_space = {"num_topics": Categorical([50,70,100,120,150]), "n_iter": Categorical([100]), "alpha": Categorical([0.01,0.05,0.1,0.5,1.0]), "eta": Categorical([0.001,0.005,0.01,0.05,0.1])}
optimizer=Optimizer()

optResult=optimizer.optimize(lda_model, fut_dataset, coherence, search_space, save_path="./outputFiles", number_of_call=30, model_runs=5)
optResult.save_to_csv("LDAgibbs_HOCoherence_futurismResults.csv")

# optResult=optimizer.optimize(lda_model, fut_dataset, kld, search_space, save_path="./outputFiles", number_of_call=30, model_runs=5)
# optResult.save_to_csv("LDA_HOKld_results.csv")

# %%
ldaTomopy_model=LDA_tomopy()
search_space = {"num_topics": Categorical([50,70,100,120,150]), "max_iters": Categorical([100]), "alpha": Categorical([0.01,0.05,0.1,0.5,1.0]), "eta": Categorical([0.001,0.005,0.01,0.05,0.1])}
optimizer=Optimizer()

optResult=optimizer.optimize(ldaTomopy_model, fut_dataset, coherence, search_space, save_path="./outputFiles", number_of_call=30, model_runs=5)
optResult.save_to_csv("E:\\Rashi\\octis\\outputFiles\\Futurism\\LDAtomopy_HOCoherence_futurismResults.csv")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
#sortValues
df=pd.read_csv('E:\\Rashi\\octis\\outputFiles\\Futurism\\NMFscikit_HOCoherence_futurismResults.csv')
df.sort_values(by='Median(model_runs)',inplace=True, ascending=False)
df.to_csv('E:\\Rashi\\octis\\outputFiles\\Futurism\\NMFscikit_HOCoherence_futurismResults.csv')

# %%
LDAgibbs - OptimizedHP

# %%
#NMFscikit - optimizedHP
nmf_model = NMF_scikit(num_topics=50, init='nndsvda', alpha=0.0)
nmf_output = nmf_model.train_model(fut_dataset)
print('Topics:',*[' '.join(x) for x in nmf_output['topics']],sep='\n')

coherence = Coherence(texts=fut_dataset.get_corpus(), topk=10, measure='c_v')
kld = KLDivergence()

print(f'\nOverall Coherence Score: {coherence.score(nmf_output)}  \nKLD Score: {kld.score(nmf_output)}')
# Out:
# Topics:
# prime amazon day deal good save echo big dog espresso
# musk twitter elon speech account company tesla tweet platform free
# musk spacex elon tesla starship ceo insider employee company woman
# station space iss nasa astronaut international crew russia russian cosmonaut
# climate change study human researcher scientist disease rogan sea city
# game play vr roblox console gamer genre player title good
# headphone ear noise earbud sound audio wireless pair music cancel
# tv inch k screen qle smart television refresh light rate
# tesla drive self car driver vehicle autopilot fsd beta driving
# ftx bankman fry sbf sam crypto exchange collapse ceo fund
# controller nintendo switch console xbox game gaming x play ole
# fusion energy reactor nuclear power livermore breakthrough experiment scientist claim
# nft ape bored sell blockchain nfts artist art opensea marketplace
# watch apple smartwatch garmin band gps mm fitness series wrist
# nasa launch rocket sls moon artemis mission agency lunar starship
# lemoine lamda ai sentient google sentience language claim engineer human
# metaverse meta facebook zuckerberg vr company virtual headset mark concert
# camera video shoot doorbell image autofocus sensor resolution good phone
# keyboard key mechanical razer ergonomic logitech wrist wireless huntsman switch
# printer d print printing filament vyper resin ink photo pla
# kid child parent selling binocular age young fun key gift
# crypto coinbase exchange wallet cryptocurrency investor security blockchain crash bitcoin
# tablet ipad pen screen drawing cintiq app fire pro display
# vpn server service netflix streaming vpns firestick expressvpn access nordvpn
# samsung galaxy phone s watch screen inch tab gb android
# laptop gb ram acer port chromebook graphic gaming processor usb
# solar panel generator delta power ecoflow sunpower battery max ef
# apple macbook airpod pro ipad m labor inch max generation
# drone fly axon taser board battery flight ethic minute control
# planet earth moon atmosphere jupiter orbit exoplanet star solar system
# cbd oil fat hemp gummie milligram flavor ingredient supplement cat
# ai dall image artist generate openai e neural network lensa
# universe signal dark scientist researcher paper alien matter theory galaxy
# nebulae star nebula object emission light ionize reflection mass planetary
# turntable speaker audio music album preamp sound record cartridge bulb
# selling key cook gift cooking point recipe food heat ingredient
# mattress memorial pit deal fire labor sale day bonfire weekend
# webb telescope nasa james image hubble space jwst galaxy astronomer
# gaming mouse pc pad headset desktop gamer rtx steelserie rgb
# mar sample nasa mars earth martian rover carbon rock insight
# vacuum robot dyson cleaner litter v clean cat floor sweep
# russia rogozin russian ukraine putin country ukrainian roscosmo invasion space
# report tiktok government msn company datum accord tell employee uber
# chair ergonomic desk material plastic recycle branch recyclable office sustainable
# detector metal battery radar monoxide inch treasure carbon gps device
# bitcoin mining crypto tulip taleb cryptocurrency groot miner el salvador
# satellite starlink spacex asteroid internet streak service phone launch orbit
# charge phone magsafe charger protector iphone device cable usb case
# bot chatbot health gut viome replika intelligence ai sarina chinese
# originally smart k discount tv series blender inch m uhd
#
# Overall Coherence Score: 0.7391398738996731
# KLD Score: 295.86869070622924

# %%
#optimizedHP
lda_model = LDA_gibbs(num_topics=120, n_iter=1000, random_state=100, alpha=0.1, eta=0.01)
lda_output = lda_model.train_model(fut_dataset)
print('Topics:',*[' '.join(x) for x in lda_output['topics']],sep='\n')

coherence = Coherence(texts=fut_dataset.get_corpus(), topk=10, measure='c_v')
kld = KLDivergence()

print(f'\nOverall Coherence Score: {coherence.score(lda_output)}  \nKLD Score: {kld.score(lda_output)}')
# Out:
# WARNING:lda:all zero column in document-term matrix found
# Topics:
# printer print photo hp ink airprint printing canon paper page
# star nebulae percent nebula gun black object white cluster emission
# user content social platform medium creator youtube tiktok account internet
# game controller switch console nintendo play xbox gaming android button
# recycle plastic material sustainable company percent product friendly sustainability design
# energy fusion nuclear power antimatter reactor claim produce fuel generate
# headphone noise earbud ear sound wireless audio pair music cancel
# laptop gaming gb graphic ram port card processor pc game
# planet earth system solar moon atmosphere sun orbit jupiter large
# battery hour long charge life size high small device power
# like time think people know actually thing way lot come
# grow compost plant composter garden indoor system food soil cut
# screen protector iphone glass case protection phone temper protect scratch
# like city jetpack space mayman feel drive ground solid foot
# mining interface hardware software bitcoin user platform miner ability allow
# free protection protect information software device datum security file include
# service streaming tv channel live stream month access offer sport
# country china report united government city states new american datum
# ingredient flavor include delicious food scale sauce tasty drink favorite
# like good new look way version world original hard hit
# account post twitter speech fact ban user suspend new site
# good pro spec cut con price use feature great model
# pro apple airpod usb drive new macbook inch ipad max
# researcher study scientist new university find research paper way publish
# star war set lego fan fett design piece boba character
# use create product post work find need help time like
# property sell roofstock house rental real rent home estate price
# light lead bulb color strip lighting energy control led app
# flashlight sound inch power subwoofer lumen bass car brightness bright
# surge protector outlet device power equipment protection provide joule plug
# tablet screen display app amazon inch ipad fire apple access
# dog pet camera subscription cat treat toy inch petcube fi
# cbd oil fat gummie hemp supplement milligram cat ingredient weight
# high allow feature design look system model easy build offer
# mar earth nasa life mars sample surface mission planet rock
# speed bike scooter ride mile ebike electric range battery motor
# keyboard key ergonomic mechanical wireless switch logitech type wrist inch
# design fit color look come black style water bag feel
# binocular view magnification light hold weight hand easy science mm
# wrist rest memory foam gel keyboard inch comfortable material rubber
# software digital pen art drawing tablet draw tool modeling suite
# crypto wallet bitcoin cryptocurrency exchange security coinbase blockchain cold currency
# story msn site fake hacker grime government anonymous website hack
# kid child age young old parent fun year adult time
# gps tracker track garmin feature tracking fitness smartwatch life location
# game play gamer player space xbox genre title release online
# language app learn lesson workout learning liteboxer subscription grandpad contact
# vpn server service speed access country app location fast hotspot
# deal day sale originally good mattress discount labor black post
# tesla car drive vehicle self driver feature software safety autopilot
# nft ape sell crypto blockchain artist art nfts project collection
# gaming razer headset pc wireless ps gamer sound rgb wire
# musk twitter elon ceo tesla company spacex billionaire buy tweet
# chair ergonomic support desk office home day height work adjustable
# robot vacuum clean litter cat floor machine dyson cleaner sweep
# tv inch screen smart television rate series picture refresh game
# twitter com pic meme tweet post february co user image
# year time accord report new read announce remain come week
# tell company read public write argue expert risk accord concern
# watch apple series band smartwatch mm screen model wear display
# video look frame system resolution second set find room view
# metaverse meta facebook company virtual zuckerberg board mark reality public
# charge device charger magsafe apple power cable phone iphone usb
# device inch come little easy great use weight build run
# ftx fry bankman crypto exchange sbf sam ceo collapse fund
# door garage opener smart close app open mazda pyramid access
# foot massager massage heat setting remote flow mode rain control
# money investor million billion company pay dollar percent buy month
# oil animal sea neuralink science spider spill eye cell environmental
# case phone waterproof water ip rating build drop protection dry
# signal alien civilization object team paper extraterrestrial like peer wormhole
# mug ember coffee cube temperature morning drink cup hot machine
# dj software audio music track pro djs support feature hardware
# roblox online card ring father popular lord robux power fan
# ai generate image machine artist algorithm create use network result
# samsung galaxy phone android google gb life battery mp screen
# vr headset user experience reality controller visual quest virtual playstation
# camera video image resolution shoot high capture quality megapixel lens
# day prime amazon deal good save big great echo score
# oven cook heat cooking air food kitchen grill temperature control
# hdmi modulator school splitter student home output college need input
# satellite phone service hour starlink talk plan coverage iridium send
# monitor hoverboard arm display desk inch stand work mount pound
# claim law report read tell case use court police department
# hair water shark dry attachment tool heat skin styling flexstyle
# park center woman national report local military program agency ufos
# nasa launch space rocket mission spacex astronaut moon agency starship
# bot people man chatbot relationship nyt york tell feel behavior
# time massive hour ray second inside far case turn high
# climate change find tree environment impact increase mosquito winter disaster
# solar panel power generator ecoflow delta max charge ef outlet
# space universe telescope webb star light matter galaxy nasa dark
# human life write person experience brain describe home live iq
# use company like recommend allow lot want feature time big
# sensor shoot wildlife photographer wedding body frame excellent capability autofocus
# health sleep test intelligence gut medical food viome service know
# fire employee company work trump worker email insider leak new
# watch green golf eye distance display gps wear course touch
# ai lemoine google claim lamda human sentient engineer language consciousness
# key point good selling gift great dad love perfect kit
# drone fly control flight minute inch time helicopter mini easy
# ice cream smart machine scoop like summer breville gorgeous batch
# photo edit editing program adobe image software app tool premiere
# metal detector inch treasure gold use coil pound beginner hunter
# mouse pad surface gaming desk hard mousepad inch cloth non
# printer print machine printing piece equipment espresso family air fitness
# cool pad laptop fan air usb rpm heat powerful setting
# kindle wallet card book reader read credit paperwhite rfid block
# space russia station russian iss nasa international rogozin ukraine astronaut
# death dead ticket body ticketmaster add die state funeral price
# printer filament print pla material printing vyper temperature resin degree
# detector aid radar hearing hear carbon monoxide detect use technology
# microphone webcam record mic quality audio good capture recording clear
# company technology tell new tech world build digital people project
# smart home doorbell video camera wifi alexa security google house
# headphone sound ear studio frequency audio design response open quality
# speaker turntable audio sound music receiver av record album play
# rogan royalty lg song xboom john joe music stupid valentine
# mac software pro user music tool system production audio effect
# projector talkie walkie use portable range channel mini radio echo
#
# Overall Coherence Score: 0.6305559469122756
# KLD Score: 5.346551788738352

# %%
#optimizedHP - 2x Topics
lda_model = LDA_gibbs(num_topics=240, n_iter=1000, random_state=100, alpha=0.1, eta=0.01)
lda_output = lda_model.train_model(fut_dataset)
print('Topics:',*[' '.join(x) for x in lda_output['topics']],sep='\n')

coherence = Coherence(texts=fut_dataset.get_corpus(), topk=10, measure='c_v')
kld = KLDivergence()

print(f'\nOverall Coherence Score: {coherence.score(lda_output)}  \nKLD Score: {kld.score(lda_output)}')
# Out:
# WARNING:lda:all zero column in document-term matrix found
# Topics:
# nebulae nebula star cloud object emission gas fact surround comprise
# screen protector glass case iphone protection temper protect pack phone
# concert fan ticket ticketmaster swift demand join begin speak venue
# game switch nintendo console classic title ole retro include experience
# high low provide run type unit cost performance brand power
# pet camera dog treat cat toy subscription petcube control parent
# webb telescope nasa space james image hubble year early agency
# weight pound light easy inch size need level small heavy
# build create day long like way goal time thing fast
# ftx bankman fry exchange crypto sbf sam ceo collapse fund
# cable flow iii mess wrap realize tie thick braid durability
# gaming pc graphic core machine processor high rate port usb
# creator site trump deepfake porn royalty adult digital content account
# tv channel live sport offer news cable month content hulu
# world year like real time long life early old come
# press record ice past bad ap sea level associate break
# free subscription system access month cost pay fee monthly unlimited
# desk plate control box standing frame screw assembly contact direct
# star close light discover observation astronomer sun million know hole
# post issue suit pressure shut major drop security fellow internet
# player online xbox series mode multiplayer single doom gear rating
# eye use monitor mira think ink touch book fill useful
# case phone waterproof water ip drop protection dry seal rating
# allow long ability range technology market end able addition thank
# allow design use feature recommend lot want like support mean
# star set war lego piece fett boba original fan character
# app use time set button like home large run phone
# service streaming stream like internet device netflix library live home
# radar detector binocular detect magnification speed use trap technology alert
# property sell roofstock rental price estate home real rent market
# apple pro macbook new ipad display inch max performance air
# change face picture mask cow result ability guardian interesting viral
# light lead color lighting control room app foot bright google
# good pro spec cut price con look model like feature
# game play gaming gamer console title gameplay playstation spec pc
# cbd fat oil product supplement cat ingredient weight spectrum burner
# headset robot ps robotic immersive beach gen sony stealth turtle
# accord time report read new tell year come far tweet
# rest wave help natural leave shape long pressure position lift
# human party medium instagram motherboard influencer leader political hazy social
# tesla drive self driver car software vehicle feature beta safety
# space station iss nasa russia russian international astronaut rogozin crew
# nasa moon mission astronaut agency surface lunar artemis launch plan
# oven cook food cooking air kitchen recipe fry breville freak
# foot massager massage setting mode shiatsu heat cord control relief
# coffee mug morning temperature cup hot ember machine shot tech
# flashlight lumen mah alkaline brightness construction pocket bright rechargeable aluminum
# energy fusion nuclear power antimatter reactor produce generate plant source
# photo facial search child image recognition provide identify mineral soldier
# vacuum robot clean floor dyson cleaner sweep room machine mess
# heat grill series gravity cricut temperature project masterbuilt charcoal griddle
# water report find ocean sea low dry area region drought
# artist art work image generate lensa user style profile character
# tracker car gps location alert track time vehicle real cost
# crypto exchange cryptocurrency coinbase security bitcoin blockchain currency investor asset
# solar panel power generator delta ecoflow max use ef hour
# bone conduction fit run rating spirit aeropex build size microphone
# controller xbox switch button play wireless bluetooth pro usb joy
# valentine equally chocolate magic geese truth device powerful harassment humble
# charge device power usb charger wireless plug station charging fast
# metaverse meta facebook virtual company zuckerberg world mark build user
# dj software audio track pro djs music support hardware feature
# country russia china ukraine russian ukrainian war putin united europe
# kid child age young old parent fun adult control friendly
# smart door garage opener home close open camera app simple
# headphone noise sound response frequency hz cancel look set connection
# claim tail cluster base mcafee creator prove wright john norwegian
# band leather nylon stretch wristband material strap accent day non
# tv port set video frame second setting find look hdmi
# account post free ban suspend speech sweeney fact track elonjet
# power subwoofer sound inch car bass great good watt quality
# post sale time create non product link receive day portion
# sleep mom app night body inside asleep fall help cbdistillery
# device protection software antivirus package malware file free information feature
# think work know thing lot people like big time pretty
# kindle book read reader amazon paperwhite page oasis digital inch
# cnn arca popescu octopus note octopi resource heavy farming ecorocket
# language learn lesson app new program learning course skill minute
# bot covid people pandemic zoom score sentiment chinese theory negative
# software tool modeling digital suite art package powerful design type
# ice cream smart machine scoop breville bowl freezer mix churn
# server country content netflix ip expressvpn offer speed free customer
# vr headset controller quest reality user playstation experience virtual motion
# money billion investor million pay worth world fund firm cash
# watch feature smartwatch tracking track fitness smartwatche include text sleep
# originally twin blender th mixer square july memory standard kitchenaid
# tesla vehicle car electric ev group evs lithium state solid
# park national piano grand book community table gorgeous visit coast
# hotspot liteboxer carrier month high workout country punch verizon hour
# use option include offer need feature good easy find work
# ai lemoine google claim lamda human sentient language researcher engineer
# board student school axon dr course smith taser statement motherboard
# echo sony discount smart speaker system jbl series dot hd
# science telescope step ground tie candle pyramid project scan void
# cube ember medical food health drug doctor temperature transport rapamycin
# employee company work email fire worker gun document feel office
# year human death dead body dna california able funeral san
# grow plant garden indoor system nutrient small plastic require unit
# shirt bitcoin cryptocurrency size guide logo hat dad invest enthusiast
# object mass energy speed material particle travel size estimate infinite
# grow meat crop cell plant produce hadfield process cannabis glyphosate
# turntable record album preamp usb manual cartridge needle vinyl build
# high system quality capability technology value select connectivity professional old
# detector metal carbon monoxide device inch battery treasure gold coil
# sell real house digital sale million buy diamond virtual auction
# printer print photo hp ink airprint canon printing image page
# surge protector outlet ac protection equipment joule cover protect fault
# espresso drink milk water spice pull bar de hit infusion
# mar earth life nasa sample mars planet form survive rock
# camera shoot image sensor video body lens photography megapixel capture
# inch device use dimension work need weight pound require power
# deal mattress black friday good price holiday discount check item
# woman police cook apple airtag department local application arm manner
# vice military father sun ufos government interview pentagon document defense
# magsafe iphone charger phone watt apple charge belkin case compatible
# laptop gb ram gaming card drive graphic computer chromebook power
# airpod pro apple generation second new sound consistent difference process
# bubble wormhole black quantum hole physicist consciousness physics water long
# aid hearing hear feature warranty ear help style loss model
# read new york tell report claim accord use times case
# planet earth atmosphere solar system moon orbit jupiter surface large
# gaming razer rgb gamer steelserie pc rig game great huntsman
# tablet app amazon fire access tab inch storage senior performance
# release genre platform experience graphic action visual puzzle date sky
# insider accord leak uber message cofounder kalanick son corporate hot
# buzzfeed song favorite joke account music fan reply poop amazon
# dad father water parent baby boat pencil piece bird shed
# battery life charge hour long mode power small performance pack
# ai machine create intelligence use result network generate image artificial
# bitcoin mining hardware interface software user miner platform rig coin
# editing edit program photo adobe image software app tool editor
# question ask answer want speak actually people know need public
# phone android mp emulator google play gaming mobile smartphone camera
# vpn access number location app protocol fast vpns firestick address
# model change open trail source positive bear follow error version
# company year million send people service founder ceo concept commercial
# recycle product plastic sustainable company material percent sustainability friendly design
# story wall fake head journal job hit street drug actually
# sexual woman child insider cnbc sex friend abuse entire story
# gate weird george april epstein bush french bill neo ufc
# spin crawler animal habitat provide asteroid concept creature center wildlife
# galaxy samsung google gb new os storage classic watch phone
# signal alien life civilization planet exoplanet extraterrestrial telescope earth paper
# appear crungus luxury tiffany cryptopunk brand kelly alexandre nftiff pendant
# earbud headphone noise wireless ear sound pair audio active music
# fly jetpack flight mayman foot aviation train city pilot future
# flavor cbd gummie bottle milligram hemp use package organic gummy
# projector lg portable movie picture sound room xboom quality theater
# bike ebike assist pedal wh power frame rider provide capacity
# bulb energy led efficient smart available hub incandescent lifespan white
# dog tracker gps track fitness subscription collar help fi health
# smart video doorbell home camera security eufy record ring storage
# filament pla material printer temperature degree finish celsius print carbon
# great good deliver important job end usually system issue think
# human brain animal neuralink experiment expert ultimately monkey test child
# watch apple series mm band screen accessory model smartwatch size
# nft ape project crypto blockchain nfts sell bored steal token
# satellite starlink spacex anti government internet test debris asteroid grant
# chatbot relationship bot user post man real love replika behavior
# compost composter green material turn food lomi worm soil break
# insight mazda genki dust shadowcast storm tune driver seattle lander
# garmin watch solar workout training instinct run music sport course
# content youtube platform copyright social creator pay facebook online popular
# hair scale flexstyle heat styling dry attachment tool shark style
# tablet pen ipad pro draw drawing digital control cintiq laptop
# speed wifi datum mobile network internet service device plan connect
# television samsung qle stand class smart mount optimize neo sound
# deal day labor good sale weekend buy discount fire school
# studio design response accurate frequency user sony profile heavy available
# use need year require big small inside new end little
# litter cat machine box robot perform waste cycle week miku
# user contact grandpad website photo add code sign message marketing
# website hacker web site government hack attack access probably sponsor
# technology industry attempt tech report bill business october group consumer
# space earth fly private look travel bezos launch billionaire mission
# school bag college key student selling point backpack lunch box
# tv inch smart rate series refresh lead picture technology gaming
# fire pit stove house solo smoke memorial bonfire cause flame
# eye science msn human bbc vision comment patient bowie implant
# monitor arm desk display mount work stand low setup pound
# health test intelligence gut viome iq food service measure score
# drone fly control minute inch camera helicopter flight time video
# people black percent white family bolden minority institution way young
# keyboard key mechanical ergonomic wireless type switch logitech wrist usb
# like feel new look experience far turn life person consider
# launch rocket space spacex starship sls cost engine test orbit
# twitter com pic meme co february credit post april online
# scientist researcher study new team university find paper year research
# drive usb flash file gb datum safe fit type fast
# good like great available pro plenty popular cut include store
# modulator home cable rf signal entertainment definition channel thankfully especially
# scooter speed ride mile electric range road motor max high
# come little easy way build especially provide run simply different
# grime fair baby anonymous shark walk secret boucher guy nearly
# video record vlogge accessory smartphone footage recording youtube hero vlogger
# oil spill damage skin sun protect disaster bad accident chemical
# cool pad laptop fan usb air rpm power powerful heat
# headphone sound ear audio quality open comfortable pair cable music
# hoverboard hour speed wheel motor reach mile road tire lead
# key good point selling gift kit include love perfect way
# material set tool outer recyclable furniture buy single drill manufacturing
# movie content film ring original video clone lord hbo book
# law reuter legal reuters allow lawsuit rule revenue eu illegal
# matter force dark particle gravitational probe live tiny spacecraft distance
# program letter fight money customer plan analysis ubisoft finish paper
# strip length adhesive connector mate clip sensor duovox flexible ir
# musk elon twitter tesla ceo spacex company tweet buy billionaire
# evolution group evidence theory belief human write natural states united
# screen display resolution size color bright big device pixel large
# music software tool production mac user audio system sound pro
# spider border bug mosquito specie thermacell area barrier local cartridge
# catch float begin war purpose animal logsdon patch peace virt
# force event snoop cox culture senior conference dig gagarin yuri
# twitter platform social speech free medium company user source content
# webcam video view resolution model quality focus field microphone home
# air home purifier clean plus room filter large quality insight
# chair ergonomic support office home day sit adjustable material height
# hdmi output splitter screen input port connect television switch video
# fitness equipment family exercise build health telescope easily kit celestron
# roblox experience spend robux anime raise gorgeous arsenal money card
# tell like people thing think know way note point believe
# winter snow drop rain water day window hot pattern night
# design color look work black fit water come style sleek
# speaker audio sound music receiver av play stereo listen bluetooth
# mouse pad wrist surface foam memory rest hard gel inch
# day prime amazon deal good save big great echo score
# heat control temperature degree cool water fahrenheit high layer apply
# printer print printing piece resin vyper allow model anycubic percent
# city kqi country resident new place live bird north crow
# tree board cool wine idea minute blanket member box eco
# climate change human environment environmental world population global century impact
# wallet card cold rfid block key credit hot storage nano
# sneaker cygni cariuma repeat taleb summer inspire bb book heart
# datum use risk government report concern tiktok algorithm privacy potentially
# microphone mic gaming capture record recording hyperx quadcast audio stand
# ray sonos object loeb soundbar comet space meteor center interstellar
# watch gps golf distance green course club wear allow provide
# write describe shatner boo home feeling emotional academic awe chappelle
# universe galaxy dark time theory suggest light matter gravity bang
# satellite phone talkie walkie hour talk weather channel iridium coverage
#
# Overall Coherence Score: 0.5879168300581998
# KLD Score: 5.0929435811001476

# %%
pip install "gensim>=4.2.0,<5.0" nltk pandas spacy "scikit-learn==1.1.0" "scikit-optimize>=0.8.1" matplotlib torch "numpy>=1.23.0,<2.0" libsvm flask sentence-transformers requests tomotopy "scipy<1.13"

# %%
#LDAtomopy - optimizedHP
ldaTomopy_model = LDA_tomopy(num_topics=70, max_iters=100, alpha=0.1, eta=0.05)
ldaTomopy_output = ldaTomopy_model.train_model(fut_dataset)
print('Topics:',*[' '.join(x) for x in ldaTomopy_output['topics']],sep='\n')

coherence = Coherence(texts=fut_dataset.get_corpus(), topk=10, measure='c_v')
kld = KLDivergence()

print(f'\nOverall Coherence Score: {coherence.score(ldaTomopy_output)}  \nKLD Score: {kld.score(ldaTomopy_output)}')
# Out:
# Topics:
# green grandpad case attorney cluster court star contact claim audible
# selling key point gift good hair kit include love great
# snow b ufos osiris hot star mcafee nebula cygni bellerophon
# doorbell smart video hp home ring security eufy blink storage
# oven cook cooking food kitchen heat grill temperature breville recipe
# aid hearing hear ear model warranty battery fit bluetooth sound
# printer d print printing piece panel resin anycubic screen fitness
# kid tablet child age app screen young parent old senior
# controller switch xbox game nintendo button play wireless gaming bluetooth
# vyper bubble airtag skin sunscreen spray reznor sun plate water
# good feature pro use price high include cut model spec
# meta metaverse facebook zuckerberg virtual vr tiktok mark reality datum
# space russia station russian iss ukraine rogozin international nasa astronaut
# bot chatbot ai user facial post search photo chinese recognition
# light energy fusion lead strip power ray nuclear lighting sonos
# hdmi modulator splitter output input cable signal device rf home
# nft ape project crypto sell tool software production digital blockchain
# monitor arm display desk vk screen pen scale mount stand
# use time app allow work set like new support find
# mouse pad gaming cool surface microphone laptop fan inch desk
# binocular wrist x rest material memory foam gel inch plastic
# robot litter cat box machine clone shark walk robotic whisker
# wallet card rfid color material block slim credit black carbon
# d software modeling tool free max ds game character type
# lego star war set jetpack mayman fett boba piece fan
# tv inch screen samsung k smart television lead refresh rate
# mattress black friday deal sale sleep memorial green discount holiday
# phone printer case photo print ink waterproof mp screen airprint
# evolution science eye animal experiment brain neuralink monkey theory crop
# turntable album record preamp usb manual audio needle build cartridge
# like come look post time use light good little day
# report country government accord china use read risk new department
# grow plant recycle solar plastic material indoor garden product sustainable
# speaker music sound audio stereo song zeppelin stream n lg
# game vr play headset nintendo console experience switch title like
# ai image artist language generate algorithm network write model lensa
# watch apple galaxy garmin s smartwatch gps battery screen feature
# tesla vehicle car drive self driver software autopilot musk beta
# musk twitter elon tesla spacex ceo tweet speech employee account
# tracker gps battery talkie walkie dog flashlight range location life
# battery speed bike ebike scooter hoverboard mile ride m range
# video editing premiere adobe mac software pro edit imovie final
# human researcher scientist tell study research find university technology ai
# company tell year like people time know new world come
# planet star earth scientist universe life team signal theory new
# ice cream scoop smart machine msn youtube story churn bowl
# bush boo george neo chappelle bst kitty w hawk dril
# vpn service server speed streaming firestick gaming internet country location
# telescope nasa webb space image james heat science jupiter shatner
# nasa space launch mission rocket spacex moon mar agency year
# keyboard chair key ergonomic mechanical wireless logitech inch office switch
# device inch x good android pro spec weight run play
# climate park city change tree water sea national drought river
# sleep cricut heat dna legging tentree easypress mom project press
# fire subwoofer pit power labor inch bass car sound watt
# laptop gaming gb graphic ram processor card screen port game
# battery satellite phone smart garage door v opener lithium hour
# day prime deal amazon good save big echo great smart
# vacuum robot property roofstock clean dyson sell floor cleaner rental
# drone fly battery control minute flight helicopter camera time inch
# crypto wallet bitcoin mining cryptocurrency security software interface exchange hardware
# porn epstein adult onlyfan gate fedex snow winter performer permission
# detector metal radar carbon detect monoxide inch battery treasure device
# headphone sound ear audio noise wireless airpod earbud pro studio
# pet camera cat dog treat subscription toy petcube home way
# ftx crypto bankman fry exchange investor fund ceo sam billion
# cbd oil fat health gummie hemp milligram ingredient supplement gut
# liteboxer workout ticketmaster ticket punch concert song fan strength swift
# charge cable protector device power case phone station usb surge
# camera video resolution image webcam sensor shoot k megapixel body
#
# Overall Coherence Score: 0.5827027736830857
# KLD Score: 3.1519999265044807
